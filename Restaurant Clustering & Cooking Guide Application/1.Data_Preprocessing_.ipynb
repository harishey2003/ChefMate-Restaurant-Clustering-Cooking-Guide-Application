# %%
pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import boto3
import os
from dotenv import load_dotenv

# %% [markdown]
# # Data_Preprocessing
# s3 Bucket connection

# %% [markdown]
# uploading the given data set for project to the AWS s3 bucket

# %%
import boto3

# Authentication credentials for AWS account
Access_key = "AKIAXWHDMFUNQTPVBMQP"
Secret_key = "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"

# Configuration setup for boto3 S3 client
s3_client = boto3.client(
    's3',
    aws_access_key_id=Access_key,
    aws_secret_access_key=Secret_key
)

# Bucket name
bucket_name = "restaurantdata-bucket"

# List objects (files) in the bucket
response = s3_client.list_objects_v2(Bucket=bucket_name)

# Check if the bucket has any files
if 'Contents' in response:
    print(f"Files in {bucket_name}:")
    for obj in response['Contents']:
        print(f" - {obj['Key']}")  # Display file names
else:
    print(f"No files found in {bucket_name}.")
# Out:
# Files in restaurantdata-bucket:
#  - file1.json
#  - file2.json
#  - file3.json
#  - file4.json
#  - file5.json

# %%
#list of buckets
buckets = s3_client.list_buckets()

buckets
# Out:
# {'ResponseMetadata': {'RequestId': 'X1RCZ74QKTHHH0F5',
#   'HostId': 'JWm8e2sOdgiVjuGqRW9w0sNQd40qRfUVn4ZOKcRukZq8zBGZYPXsbXbRHrziwhcaWj6gOjv7CWg=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'JWm8e2sOdgiVjuGqRW9w0sNQd40qRfUVn4ZOKcRukZq8zBGZYPXsbXbRHrziwhcaWj6gOjv7CWg=',
#    'x-amz-request-id': 'X1RCZ74QKTHHH0F5',
#    'date': 'Mon, 16 Dec 2024 17:21:29 GMT',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Buckets': [{'Name': 'restaurantdata-bucket',
#    'CreationDate': datetime.datetime(2024, 12, 12, 6, 50, 11, tzinfo=tzutc())}],
#  'Owner': {'DisplayName': 'harishkumar24480',
#   'ID': '6bc6971b6ad10aef519e3bc5ae3d9fac1ac363810ad203d0c2f0adfbb9b1b9f9'}}

# %%
# files inside a bucket
files = s3_client.list_objects_v2(Bucket = 'restaurantdata-bucket')
files
# Out:
# {'ResponseMetadata': {'RequestId': '5C0MBX7P1YW3F40H',
#   'HostId': 'VpeKe2Dvoms3VYTkoyOd/14sFgdiKB1Q5Uubek7I9QTOTCFTIo4xNYIQuu8N4NRWeyjzc6/mvGzzyOVw4Jkcj2b8K4a9c5/tcFaiQTpVEf8=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'VpeKe2Dvoms3VYTkoyOd/14sFgdiKB1Q5Uubek7I9QTOTCFTIo4xNYIQuu8N4NRWeyjzc6/mvGzzyOVw4Jkcj2b8K4a9c5/tcFaiQTpVEf8=',
#    'x-amz-request-id': '5C0MBX7P1YW3F40H',
#    'date': 'Mon, 16 Dec 2024 17:30:03 GMT',
#    'x-amz-bucket-region': 'eu-north-1',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'IsTruncated': False,
#  'Contents': [{'Key': 'file1.json',
#    'LastModified': datetime.datetime(2024, 12, 12, 6, 55, 25, tzinfo=tzutc()),
#    'ETag': '"1836d48625fa4019d65b5f1e80d01ee0"',
#    'Size': 2198732,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'file2.json',
#    'LastModified': datetime.datetime(2024, 12, 12, 6, 53, 57, tzinfo=tzutc()),
#    'ETag': '"7a642e55f93c02ac12f7a18285f795ac-2"',
#    'Size': 20006072,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'file3.json',
#    'LastModified': datetime.datetime(2024, 12, 12, 6, 55, 12, tzinfo=tzutc()),
#    'ETag': '"5e31aee5b2fb72444d3506b7ea8b61f9"',
#    'Size': 15610388,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'file4.json',
#    'LastModified': datetime.datetime(2024, 12, 12, 6, 54, 30, tzinfo=tzutc()),
#    'ETag': '"3de925172a8716de14a52ab130cda0f7"',
#    'Size': 16427749,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'file5.json',
#    'LastModified': datetime.datetime(2024, 12, 12, 6, 54, 1, tzinfo=tzutc()),
#    'ETag': '"8f4326824c9fc9556f43a6dd50590540"',
#    'Size': 669503,
#    'StorageClass': 'STANDARD'}],
#  'Name': 'restaurantdata-bucket',
#  'Prefix': '',
#  'MaxKeys': 1000,
#  'EncodingType': 'url',
#  'KeyCount': 5}

# %%
# files inside a folder
files_inside_folder = s3_client.list_objects_v2(Bucket ='restaurantdata-bucket',Prefix = '')
files_inside_folder
# Out:
# {'ResponseMetadata': {'RequestId': '8H5H2PHB9NXXNA73',
#   'HostId': 'NgBKRTyeIeIInSCpW10z8U9FJhaNeOm03yk93/bID4P6rEwL79KbgXC6TMgrH5YZBCPaTsAdfPlQi3APv4aDo+vWOWGu43bFTyxvf4gxJY8=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'NgBKRTyeIeIInSCpW10z8U9FJhaNeOm03yk93/bID4P6rEwL79KbgXC6TMgrH5YZBCPaTsAdfPlQi3APv4aDo+vWOWGu43bFTyxvf4gxJY8=',
#    'x-amz-request-id': '8H5H2PHB9NXXNA73',
#    'date': 'Mon, 16 Dec 2024 17:31:04 GMT',
#    'x-amz-bucket-region': 'eu-north-1',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'IsTruncated': False,
#  'Contents': [{'Key': 'file1.json',
#    'LastModified': datetime.datetime(2024, 12, 12, 6, 55, 25, tzinfo=tzutc()),
#    'ETag': '"1836d48625fa4019d65b5f1e80d01ee0"',
#    'Size': 2198732,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'file2.json',
#    'LastModified': datetime.datetime(2024, 12, 12, 6, 53, 57, tzinfo=tzutc()),
#    'ETag': '"7a642e55f93c02ac12f7a18285f795ac-2"',
#    'Size': 20006072,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'file3.json',
#    'LastModified': datetime.datetime(2024, 12, 12, 6, 55, 12, tzinfo=tzutc()),
#    'ETag': '"5e31aee5b2fb72444d3506b7ea8b61f9"',
#    'Size': 15610388,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'file4.json',
#    'LastModified': datetime.datetime(2024, 12, 12, 6, 54, 30, tzinfo=tzutc()),
#    'ETag': '"3de925172a8716de14a52ab130cda0f7"',
#    'Size': 16427749,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'file5.json',
#    'LastModified': datetime.datetime(2024, 12, 12, 6, 54, 1, tzinfo=tzutc()),
#    'ETag': '"8f4326824c9fc9556f43a6dd50590540"',
#    'Size': 669503,
#    'StorageClass': 'STANDARD'}],
#  'Name': 'restaurantdata-bucket',
#  'Prefix': '',
#  'MaxKeys': 1000,
#  'EncodingType': 'url',
#  'KeyCount': 5}

# %%
file_path = r"C:\Users\Lenovo\Downloads\project 6\data set\file1.json"

#(actual_data , bucket_name , file_saving_name)

s3_client.upload_file(file_path,'restaurantdata-bucket','datas/file1.json') #folder/filename

# %%
# Define the files to upload
files_to_upload = [
    ('file2.json', 'datas/file2.json'),
    ('file3.json', 'datas/file3.json'),
    ('file4.json', 'datas/file4.json'),
    ('file5.json', 'datas/file5.json')
]

# %%
files_to_upload = [
    (r"C:\Users\Lenovo\Downloads\project 6\data set\file2.json", "file2.json"),
    (r"C:\Users\Lenovo\Downloads\project 6\data set\file3.json", "file3.json"),
    (r"C:\Users\Lenovo\Downloads\project 6\data set\file4.json", "file4.json"),
    (r"C:\Users\Lenovo\Downloads\project 6\data set\file5.json", "file5.json"),
]

# %%
import os

print(f"Current working directory: {os.getcwd()}")
# Out:
# Current working directory: C:\Users\Lenovo\Downloads

# %%
import os

# Upload the files
for file_path, file_saving_name in files_to_upload:
    if not os.path.exists(file_path):
        print(f"Error: File {file_path} does not exist.")
        continue

    try:
        s3_client.upload_file(file_path,'restaurantdata-bucket' , file_saving_name)
        print(f"File {file_path} uploaded successfully")
    except Exception as e:
        print(f"Error uploading file {file_path}: {str(e)}")
# Out:
# File C:\Users\Lenovo\Downloads\project 6\data set\file2.json uploaded successfully
# File C:\Users\Lenovo\Downloads\project 6\data set\file3.json uploaded successfully
# File C:\Users\Lenovo\Downloads\project 6\data set\file4.json uploaded successfully
# File C:\Users\Lenovo\Downloads\project 6\data set\file5.json uploaded successfully

# %%
#for Eg:
#(bucket_name , actual_file_name , download_name)

s3_client.download_file('restaurantdata-bucket','datas/file1.json','unstructureddata')

# %% [markdown]
# # File1

# %%
# Load the dataset
data_1 = pd.read_json(r"C:\Users\Lenovo\Downloads\project 6\data set\file1.json")

# %%
data_1
# Out:
#      results_found                                        restaurants  \
# 0          17151.0  [{'restaurant': {'has_online_delivery': 1, 'ph...
# 1           4748.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 2          13786.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 3          10224.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 4           7039.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# ..             ...                                                ...
# 474            NaN                                                NaN
# 475            NaN                                                NaN
# 476            NaN                                                NaN
# 477            NaN                                                NaN
# 478            NaN                                                NaN
#
#      results_shown  results_start             message   code status
# 0             20.0            1.0                 NaN    NaN    NaN
# 1             20.0            1.0                 NaN    NaN    NaN
# 2             20.0            1.0                 NaN    NaN    NaN
# 3             20.0            1.0                 NaN    NaN    NaN
# 4             20.0            1.0                 NaN    NaN    NaN
# ..             ...            ...                 ...    ...    ...
# 474            NaN            NaN  API limit exceeded  440.0
# 475            NaN            NaN  API limit exceeded  440.0
# 476            NaN            NaN  API limit exceeded  440.0
# 477            NaN            NaN  API limit exceeded  440.0
# 478            NaN            NaN  API limit exceeded  440.0
#
# [479 rows x 7 columns]

# %%
# drop column from dataframe
data_1.drop(columns=["results_found","results_shown","results_start","message","code","status"],inplace=True,axis=1)

# %%
data_1
# Out:
#                                            restaurants
# 0    [{'restaurant': {'has_online_delivery': 1, 'ph...
# 1    [{'restaurant': {'has_online_delivery': 0, 'ph...
# 2    [{'restaurant': {'has_online_delivery': 0, 'ph...
# 3    [{'restaurant': {'has_online_delivery': 0, 'ph...
# 4    [{'restaurant': {'has_online_delivery': 0, 'ph...
# ..                                                 ...
# 474                                                NaN
# 475                                                NaN
# 476                                                NaN
# 477                                                NaN
# 478                                                NaN
#
# [479 rows x 1 columns]

# %%
data_1.columns
# Out:
# Index(['restaurants'], dtype='object')

# %%
# Initialize an empty list to hold restaurant data
restaurants = []

# Extract the restaurant data from the nested structure
for restaurant_list in data_1['restaurants']:
    # Check if the restaurant_list is a list
    if isinstance(restaurant_list, list):  # Ensure it's a list before iterating
        for restaurant in restaurant_list:  # Each restaurant_list contains individual restaurant dictionaries
            if 'restaurant' in restaurant:  # Check if 'restaurant' key exists
                restaurants.append(restaurant['restaurant'])  # Append the 'restaurant' dictionary to the list

# %%
# Create a new DataFrame from the list of restaurant dictionaries
data_1 = pd.DataFrame(restaurants)

# %%
data_1.columns
# Out:
# Index(['has_online_delivery', 'photos_url', 'url', 'price_range', 'apikey',
#        'user_rating', 'R', 'name', 'cuisines', 'is_delivering_now', 'deeplink',
#        'menu_url', 'average_cost_for_two', 'book_url', 'switch_to_order_menu',
#        'offers', 'has_table_booking', 'location', 'featured_image',
#        'zomato_events', 'currency', 'id', 'thumb', 'establishment_types',
#        'events_url', 'order_deeplink', 'order_url'],
#       dtype='object')

# %%
# Step 1: Extract relevant columns
columns_of_interest = [
    'has_online_delivery', 'price_range','user_rating', 'R', 'name', 'cuisines', 
    'is_delivering_now', 'average_cost_for_two', 'switch_to_order_menu',
    'has_table_booking', 'location','currency', 'id'
]

# %%
# Check if columns of interest exist in the DataFrame
existing_columns = [col for col in columns_of_interest if col in data_1.columns]
print("Existing columns:", existing_columns)  # Print the existing columns to see what's available
# Out:
# Existing columns: ['has_online_delivery', 'price_range', 'user_rating', 'R', 'name', 'cuisines', 'is_delivering_now', 'average_cost_for_two', 'switch_to_order_menu', 'has_table_booking', 'location', 'currency', 'id']

# %%
# Extract the relevant columns
data_1 = data_1[existing_columns]

# %%
data_1
# Out:
#       has_online_delivery  price_range  \
# 0                       1            3
# 1                       0            3
# 2                       1            2
# 3                       0            3
# 4                       0            3
# ...                   ...          ...
# 1175                    0            3
# 1176                    0            3
# 1177                    0            3
# 1178                    0            3
# 1179                    0            3
#
#                                             user_rating                     R  \
# 0     {'rating_text': 'Very Good', 'rating_color': '...    {'res_id': 308322}
# 1     {'rating_text': 'Excellent', 'rating_color': '...  {'res_id': 18037817}
# 2     {'rating_text': 'Very Good', 'rating_color': '...    {'res_id': 312345}
# 3     {'rating_text': 'Very Good', 'rating_color': '...    {'res_id': 307490}
# 4     {'rating_text': 'Very Good', 'rating_color': '...  {'res_id': 18241537}
# ...                                                 ...                   ...
# 1175  {'rating_text': 'Very Good', 'rating_color': '...   {'res_id': 7602340}
# 1176  {'rating_text': 'Excellent', 'rating_color': '...   {'res_id': 7600217}
# 1177  {'rating_text': 'Excellent', 'rating_color': '...   {'res_id': 7601577}
# 1178  {'rating_text': 'Good', 'rating_color': '9ACD3...   {'res_id': 7602224}
# 1179  {'rating_text': 'Good', 'rating_color': '9ACD3...   {'res_id': 7600118}
#
#                             name  \
# 0               Hauz Khas Social
# 1     Qubitos - The Terrace Cafe
# 2                The Hudson Cafe
# 3              Summer House Cafe
# 4                    38 Barracks
# ...                          ...
# 1175               The Boozy Cow
# 1176                 La Favorita
# 1177           Roseleaf Bar Cafe
# 1178                   Civerinos
# 1179             The Hanging Bat
#
#                                                cuisines  is_delivering_now  \
# 0            Continental, American, Asian, North Indian                  0
# 1     Thai, European, Mexican, North Indian, Chinese...                  0
# 2                   Cafe, Italian, Continental, Chinese                  0
# 3                                  Italian, Continental                  0
# 4                North Indian, Italian, Asian, American                  0
# ...                                                 ...                ...
# 1175                                      Burger, Grill                  0
# 1176                                            Italian                  0
# 1177                                     Scottish, Cafe                  0
# 1178                                     Pizza, Italian                  0
# 1179                                           American                  0
#
#       average_cost_for_two  switch_to_order_menu  has_table_booking  \
# 0                     1600                     0                  1
# 1                     1500                     0                  1
# 2                      850                     0                  0
# 3                     1850                     0                  1
# 4                     1600                     0                  1
# ...                    ...                   ...                ...
# 1175                    40                     0                  0
# 1176                    30                     0                  0
# 1177                    45                     0                  0
# 1178                    35                     0                  0
# 1179                    35                     0                  0
#
#                                                location currency        id
# 0     {'latitude': '28.5542851000', 'address': '9-A ...      Rs.    308322
# 1     {'latitude': '28.6471325000', 'address': 'C-7,...      Rs.  18037817
# 2     {'latitude': '28.6949468000', 'address': '2524...      Rs.    312345
# 3     {'latitude': '28.5525204000', 'address': '1st ...      Rs.    307490
# 4     {'latitude': '28.6330248887', 'address': 'M-38...      Rs.  18241537
# ...                                                 ...      ...       ...
# 1175  {'latitude': '55.9519740000', 'address': '17 F...        £   7602340
# 1176  {'latitude': '55.9646694444', 'address': '325-...        £   7600217
# 1177  {'latitude': '55.9766440000', 'address': '23-2...        £   7601577
# 1178  {'latitude': '55.9496370000', 'address': '5 Hu...        £   7602224
# 1179  {'latitude': '55.9456222222', 'address': '133 ...        £   7600118
#
# [1180 rows x 13 columns]

# %%
# If necessary, flatten the 'location' and 'user_rating' dictionaries
data_1['latitude'] = data_1['location'].apply(lambda x: x.get('latitude', None) if isinstance(x, dict) else None)
data_1['longitude'] = data_1['location'].apply(lambda x: x.get('longitude', None) if isinstance(x, dict) else None)
data_1['city'] = data_1['location'].apply(lambda x: x.get('city', None) if isinstance(x, dict) else None)
data_1['address'] = data_1['location'].apply(lambda x: x.get('address', None) if isinstance(x, dict) else None)
data_1['country_id'] = data_1['location'].apply(lambda x: x.get('country_id', None) if isinstance(x, dict) else None)
data_1['locality_verbose'] = data_1['location'].apply(lambda x: x.get('locality_verbose', None) if isinstance(x, dict) else None)
data_1['locality'] = data_1['location'].apply(lambda x: x.get('locality', None) if isinstance(x, dict) else None)

data_1['aggregate_rating'] = data_1['user_rating'].apply(lambda x: x.get('aggregate_rating', None) if isinstance(x, dict) else None)
data_1['rating_color'] = data_1['user_rating'].apply(lambda x: x.get('rating_color', None) if isinstance(x, dict) else None)
data_1['rating_text'] = data_1['user_rating'].apply(lambda x: x.get('rating_text', None) if isinstance(x, dict) else None)
data_1['votes'] = data_1['user_rating'].apply(lambda x: x.get('votes', None) if isinstance(x, dict) else None)

# Flatten the 'R' dictionary
data_1['res_id'] = data_1['R'].apply(lambda x: x.get('res_id', None) if isinstance(x, dict) else None)

# %%
# Drop the original 'location', 'user_rating', and 'R' columns if no longer needed
data_1.drop(columns=['location', 'user_rating', 'R'], inplace=True)

# %%
data_1.drop(columns=['id'], inplace=True)

# %%
data_1.head()
# Out:
#    has_online_delivery  price_range                        name  \
# 0                    1            3            Hauz Khas Social
# 1                    0            3  Qubitos - The Terrace Cafe
# 2                    1            2             The Hudson Cafe
# 3                    0            3           Summer House Cafe
# 4                    0            3                 38 Barracks
#
#                                             cuisines  is_delivering_now  \
# 0         Continental, American, Asian, North Indian                  0
# 1  Thai, European, Mexican, North Indian, Chinese...                  0
# 2                Cafe, Italian, Continental, Chinese                  0
# 3                               Italian, Continental                  0
# 4             North Indian, Italian, Asian, American                  0
#
#    average_cost_for_two  switch_to_order_menu  has_table_booking currency  \
# 0                  1600                     0                  1      Rs.
# 1                  1500                     0                  1      Rs.
# 2                   850                     0                  0      Rs.
# 3                  1850                     0                  1      Rs.
# 4                  1600                     0                  1      Rs.
#
#         latitude  ...       city  \
# 0  28.5542851000  ...  New Delhi
# 1  28.6471325000  ...  New Delhi
# 2  28.6949468000  ...  New Delhi
# 3  28.5525204000  ...  New Delhi
# 4  28.6330248887  ...  New Delhi
#
#                                              address country_id  \
# 0             9-A & 12, Hauz Khas Village, New Delhi          1
# 1  C-7, Vishal Enclave, Opposite Metro Pillar 417...          1
# 2  2524, 1st Floor, Hudson Lane, Delhi University...          1
# 3  1st Floor, DDA Shopping Complex, Aurobindo Pla...          1
# 4     M-38, Outer Circle, Connaught Place, New Delhi          1
#
#                         locality_verbose                    locality  \
# 0           Hauz Khas Village, New Delhi           Hauz Khas Village
# 1              Rajouri Garden, New Delhi              Rajouri Garden
# 2  Delhi University-GTB Nagar, New Delhi  Delhi University-GTB Nagar
# 3                   Hauz Khas, New Delhi                   Hauz Khas
# 4             Connaught Place, New Delhi             Connaught Place
#
#   aggregate_rating rating_color rating_text votes    res_id
# 0              4.3       5BA829   Very Good  7931    308322
# 1              4.5       3F7E00   Excellent   778  18037817
# 2              4.4       5BA829   Very Good  1537    312345
# 3              4.1       5BA829   Very Good  1823    307490
# 4              4.4       5BA829   Very Good   840  18241537
#
# [5 rows x 21 columns]

# %%
data_1.shape
# Out:
# (1180, 21)

# %% [markdown]
# # File2

# %%
# Load the dataset
data_2 = pd.read_json(r"C:\Users\Lenovo\Downloads\project 6\data set\file2.json")

# %%
data_2
# Out:
#      results_found  results_start  results_shown  \
# 0          1263908             21             20
# 1          1263908             21             20
# 2          1263908             21             20
# 3          1263908             21             20
# 4          1263908             21             20
# ..             ...            ...            ...
# 545             32             21             11
# 546          17151             21             20
# 547             33             21             12
# 548          17151             21             20
# 549          17151             21             20
#
#                                            restaurants
# 0    [{'restaurant': {'R': {'res_id': 16668008}, 'a...
# 1    [{'restaurant': {'R': {'res_id': 16668008}, 'a...
# 2    [{'restaurant': {'R': {'res_id': 16668008}, 'a...
# 3    [{'restaurant': {'R': {'res_id': 16668008}, 'a...
# 4    [{'restaurant': {'R': {'res_id': 16668008}, 'a...
# ..                                                 ...
# 545  [{'restaurant': {'R': {'res_id': 18433895}, 'a...
# 546  [{'restaurant': {'R': {'res_id': 313256}, 'api...
# 547  [{'restaurant': {'R': {'res_id': 309672}, 'api...
# 548  [{'restaurant': {'R': {'res_id': 313256}, 'api...
# 549  [{'restaurant': {'R': {'res_id': 313256}, 'api...
#
# [550 rows x 4 columns]

# %%
# drop column from dataframe
data_2.drop(columns=["results_found","results_shown","results_start"],inplace=True,axis=1)

# %%
data_2
# Out:
#                                            restaurants
# 0    [{'restaurant': {'R': {'res_id': 16668008}, 'a...
# 1    [{'restaurant': {'R': {'res_id': 16668008}, 'a...
# 2    [{'restaurant': {'R': {'res_id': 16668008}, 'a...
# 3    [{'restaurant': {'R': {'res_id': 16668008}, 'a...
# 4    [{'restaurant': {'R': {'res_id': 16668008}, 'a...
# ..                                                 ...
# 545  [{'restaurant': {'R': {'res_id': 18433895}, 'a...
# 546  [{'restaurant': {'R': {'res_id': 313256}, 'api...
# 547  [{'restaurant': {'R': {'res_id': 309672}, 'api...
# 548  [{'restaurant': {'R': {'res_id': 313256}, 'api...
# 549  [{'restaurant': {'R': {'res_id': 313256}, 'api...
#
# [550 rows x 1 columns]

# %%
data_2.columns
# Out:
# Index(['restaurants'], dtype='object')

# %%
# Initialize an empty list to hold restaurant data
restaurants = []

# Extract the restaurant data from the nested structure
for restaurant_list in data_2['restaurants']:
    # Check if the restaurant_list is a list
    if isinstance(restaurant_list, list):  # Ensure it's a list before iterating
        for restaurant in restaurant_list:  # Each restaurant_list contains individual restaurant dictionaries
            if 'restaurant' in restaurant:  # Check if 'restaurant' key exists
                restaurants.append(restaurant['restaurant'])  # Append the 'restaurant' dictionary to the list

# %%
# Create a new DataFrame from the list of restaurant dictionaries
data_2 = pd.DataFrame(restaurants)

# %%
data_2.columns
# Out:
# Index(['R', 'apikey', 'id', 'name', 'url', 'location', 'switch_to_order_menu',
#        'cuisines', 'average_cost_for_two', 'price_range', 'currency', 'offers',
#        'thumb', 'user_rating', 'photos_url', 'menu_url', 'featured_image',
#        'has_online_delivery', 'is_delivering_now', 'deeplink',
#        'has_table_booking', 'events_url', 'establishment_types', 'book_url',
#        'zomato_events', 'order_url', 'order_deeplink'],
#       dtype='object')

# %%
# Step 1: Extract relevant columns
columns_of_interest = [
    'has_online_delivery', 'price_range','user_rating', 'R', 'name', 'cuisines', 
    'is_delivering_now', 'average_cost_for_two', 'switch_to_order_menu',
    'has_table_booking', 'location','currency', 'id'
]

# %%
# Check if columns of interest exist in the DataFrame
existing_columns = [col for col in columns_of_interest if col in data_2.columns]
print("Existing columns:", existing_columns)  # Print the existing columns to see what's available
# Out:
# Existing columns: ['has_online_delivery', 'price_range', 'user_rating', 'R', 'name', 'cuisines', 'is_delivering_now', 'average_cost_for_two', 'switch_to_order_menu', 'has_table_booking', 'location', 'currency', 'id']

# %%
# Extract the relevant columns
data_2 = data_2[existing_columns]

# %%
data_2
# Out:
#        has_online_delivery  price_range  \
# 0                        0            2
# 1                        0            3
# 2                        0            1
# 3                        0            2
# 4                        0            2
# ...                    ...          ...
# 10597                    1            3
# 10598                    1            3
# 10599                    1            3
# 10600                    1            3
# 10601                    0            4
#
#                                              user_rating  \
# 0      {'aggregate_rating': '3.3', 'rating_text': 'Av...
# 1      {'aggregate_rating': '4.6', 'rating_text': 'Ex...
# 2      {'aggregate_rating': '4.3', 'rating_text': 'Ve...
# 3      {'aggregate_rating': '2.9', 'rating_text': 'Av...
# 4      {'aggregate_rating': '4.1', 'rating_text': 'Ve...
# ...                                                  ...
# 10597  {'aggregate_rating': '4.3', 'rating_text': 'Ve...
# 10598  {'aggregate_rating': '4.4', 'rating_text': 'Ve...
# 10599  {'aggregate_rating': '4.3', 'rating_text': 'Ve...
# 10600  {'aggregate_rating': '4.2', 'rating_text': 'Ve...
# 10601  {'aggregate_rating': '4.9', 'rating_text': 'Ex...
#
#                           R                     name  \
# 0      {'res_id': 16668008}            Arigato Sushi
# 1        {'res_id': 801690}                    Mocha
# 2      {'res_id': 17558738}          Blue House Cafe
# 3      {'res_id': 16611701}              Star Buffet
# 4       {'res_id': 2100784}  11th Avenue Cafe Bistro
# ...                     ...                      ...
# 10597  {'res_id': 18289242}         Cyber Hub Social
# 10598       {'res_id': 799}                   Gulati
# 10599    {'res_id': 301998}             Punjab Grill
# 10600    {'res_id': 307113}                   Diggin
# 10601  {'res_id': 18345728}           Masala Library
#
#                                          cuisines  is_delivering_now  \
# 0                                           Asian                  0
# 1                      Cafe, Italian, Continental                  0
# 2                   Coffee and Tea, Mediterranean                  0
# 3                                           Asian                  0
# 4            Cafe, American, Italian, Continental                  0
# ...                                           ...                ...
# 10597  Continental, American, Asian, North Indian                  0
# 10598                       North Indian, Mughlai                  0
# 10599                                North Indian                  0
# 10600                  Italian, Continental, Cafe                  0
# 10601                               Modern Indian                  0
#
#        average_cost_for_two  switch_to_order_menu  has_table_booking  \
# 0                        25                     0                  0
# 1                       800                     0                  0
# 2                        10                     0                  0
# 3                        20                     0                  0
# 4                       400                     0                  0
# ...                     ...                   ...                ...
# 10597                  1500                     0                  1
# 10598                  1500                     0                  0
# 10599                  1600                     0                  1
# 10600                  1400                     0                  1
# 10601                  5000                     0                  0
#
#                                                 location currency        id
# 0      {'address': '14 Second Ave North, Yorkton, SK ...        $  16668008
# 1      {'address': 'CP-1, 2nd Floor, Anand Plaza, Vir...      Rs.    801690
# 2      {'address': '919 Bridge St, Vernonia, OR 97064...        $  17558738
# 3      {'address': '58 Hanbury St, Mayfield, NSW', 'l...        $  16611701
# 4      {'address': 'Opposite Assam State Museum, Digh...      Rs.   2100784
# ...                                                  ...      ...       ...
# 10597  {'address': 'Cyber Hub, DLF Cyber City, Gurgao...      Rs.  18289242
# 10598  {'address': '6, Pandara Road Market, New Delhi...      Rs.       799
# 10599  {'address': 'Pacific Mall, Tagore Garden, New ...      Rs.    301998
# 10600  {'address': 'Anand Lok Shopping Centre, Opposi...      Rs.    307113
# 10601  {'address': '21 A, Janpath, New Delhi', 'local...      Rs.  18345728
#
# [10602 rows x 13 columns]

# %%
# If necessary, flatten the 'location' and 'user_rating' dictionaries
data_2['latitude'] = data_2['location'].apply(lambda x: x.get('latitude', None) if isinstance(x, dict) else None)
data_2['longitude'] = data_2['location'].apply(lambda x: x.get('longitude', None) if isinstance(x, dict) else None)
data_2['city'] = data_2['location'].apply(lambda x: x.get('city', None) if isinstance(x, dict) else None)
data_2['address'] = data_2['location'].apply(lambda x: x.get('address', None) if isinstance(x, dict) else None)
data_2['country_id'] = data_2['location'].apply(lambda x: x.get('country_id', None) if isinstance(x, dict) else None)
data_2['locality_verbose'] = data_2['location'].apply(lambda x: x.get('locality_verbose', None) if isinstance(x, dict) else None)
data_2['locality'] = data_2['location'].apply(lambda x: x.get('locality', None) if isinstance(x, dict) else None)

data_2['aggregate_rating'] = data_2['user_rating'].apply(lambda x: x.get('aggregate_rating', None) if isinstance(x, dict) else None)
data_2['rating_color'] = data_2['user_rating'].apply(lambda x: x.get('rating_color', None) if isinstance(x, dict) else None)
data_2['rating_text'] = data_2['user_rating'].apply(lambda x: x.get('rating_text', None) if isinstance(x, dict) else None)
data_2['votes'] = data_2['user_rating'].apply(lambda x: x.get('votes', None) if isinstance(x, dict) else None)

# Flatten the 'R' dictionary
data_2['res_id'] = data_2['R'].apply(lambda x: x.get('res_id', None) if isinstance(x, dict) else None)

# %%
# Drop the original 'location', 'user_rating', and 'R' columns if no longer needed
data_2.drop(columns=['location', 'user_rating', 'R'], inplace=True)

# %%
data_2.drop(columns=['id'], inplace=True)

# %%
data_2.head()
# Out:
#    has_online_delivery  price_range                     name  \
# 0                    0            2            Arigato Sushi
# 1                    0            3                    Mocha
# 2                    0            1          Blue House Cafe
# 3                    0            2              Star Buffet
# 4                    0            2  11th Avenue Cafe Bistro
#
#                                cuisines  is_delivering_now  \
# 0                                 Asian                  0
# 1            Cafe, Italian, Continental                  0
# 2         Coffee and Tea, Mediterranean                  0
# 3                                 Asian                  0
# 4  Cafe, American, Italian, Continental                  0
#
#    average_cost_for_two  switch_to_order_menu  has_table_booking currency  \
# 0                    25                     0                  0        $
# 1                   800                     0                  0      Rs.
# 2                    10                     0                  0        $
# 3                    20                     0                  0        $
# 4                   400                     0                  0      Rs.
#
#          latitude  ...      city  \
# 0   51.2106824000  ...   Yorkton
# 1   26.8528099000  ...   Lucknow
# 2   45.8586670000  ...  Vernonia
# 3  -32.8991780000  ...  Mayfield
# 4   26.1860014826  ...  Guwahati
#
#                                              address country_id  \
# 0           14 Second Ave North, Yorkton, SK S3N 1G1         37
# 1  CP-1, 2nd Floor, Anand Plaza, Viram Khand-1, N...          1
# 2                  919 Bridge St, Vernonia, OR 97064        216
# 3                       58 Hanbury St, Mayfield, NSW         14
# 4  Opposite Assam State Museum, Dighalipukhuri, T...          1
#
#         locality_verbose     locality aggregate_rating rating_color  \
# 0       Yorkton, Yorkton      Yorkton              3.3       CDD614
# 1   Gomti Nagar, Lucknow  Gomti Nagar              4.6       3F7E00
# 2     Vernonia, Vernonia     Vernonia              4.3       5BA829
# 3     Mayfield, Mayfield     Mayfield              2.9       FFBA00
# 4  Uzan Bazaar, Guwahati  Uzan Bazaar              4.1       5BA829
#
#   rating_text votes    res_id
# 0     Average    26  16668008
# 1   Excellent   567    801690
# 2   Very Good    88  17558738
# 3     Average    11  16611701
# 4   Very Good   377   2100784
#
# [5 rows x 21 columns]

# %%
data_2.shape
# Out:
# (10602, 21)

# %% [markdown]
# # File3

# %%
# Load the dataset
data_3 = pd.read_json(r"C:\Users\Lenovo\Downloads\project 6\data set\file3.json")

# %%
data_3
# Out:
#      results_found  results_start  results_shown  \
# 0        1263908.0           41.0           20.0
# 1        1263908.0           41.0           20.0
# 2        1263908.0           41.0           20.0
# 3        1263908.0           41.0           20.0
# 4        1263908.0           41.0           20.0
# ..             ...            ...            ...
# 545            NaN            NaN            NaN
# 546            NaN            NaN            NaN
# 547            NaN            NaN            NaN
# 548            NaN            NaN            NaN
# 549            NaN            NaN            NaN
#
#                                            restaurants   code status  \
# 0    [{'restaurant': {'R': {'res_id': 2100702}, 'ap...    NaN    NaN
# 1    [{'restaurant': {'R': {'res_id': 2100702}, 'ap...    NaN    NaN
# 2    [{'restaurant': {'R': {'res_id': 2100702}, 'ap...    NaN    NaN
# 3    [{'restaurant': {'R': {'res_id': 2100702}, 'ap...    NaN    NaN
# 4    [{'restaurant': {'R': {'res_id': 2100702}, 'ap...    NaN    NaN
# ..                                                 ...    ...    ...
# 545                                                NaN  440.0
# 546                                                NaN  440.0
# 547                                                NaN  440.0
# 548                                                NaN  440.0
# 549                                                NaN  440.0
#
#                 message
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ..                  ...
# 545  API limit exceeded
# 546  API limit exceeded
# 547  API limit exceeded
# 548  API limit exceeded
# 549  API limit exceeded
#
# [550 rows x 7 columns]

# %%
# drop column from dataframe
data_3.drop(columns=["results_found","results_shown","results_start","message","code","status"],inplace=True,axis=1)

# %%
data_3
# Out:
#                                            restaurants
# 0    [{'restaurant': {'R': {'res_id': 2100702}, 'ap...
# 1    [{'restaurant': {'R': {'res_id': 2100702}, 'ap...
# 2    [{'restaurant': {'R': {'res_id': 2100702}, 'ap...
# 3    [{'restaurant': {'R': {'res_id': 2100702}, 'ap...
# 4    [{'restaurant': {'R': {'res_id': 2100702}, 'ap...
# ..                                                 ...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
#
# [550 rows x 1 columns]

# %%
data_3.columns
# Out:
# Index(['restaurants'], dtype='object')

# %%
# Initialize an empty list to hold restaurant data
restaurants = []

# Extract the restaurant data from the nested structure
for restaurant_list in data_3['restaurants']:
    # Check if the restaurant_list is a list
    if isinstance(restaurant_list, list):  # Ensure it's a list before iterating
        for restaurant in restaurant_list:  # Each restaurant_list contains individual restaurant dictionaries
            if 'restaurant' in restaurant:  # Check if 'restaurant' key exists
                restaurants.append(restaurant['restaurant'])  # Append the 'restaurant' dictionary to the list

# %%
# Create a new DataFrame from the list of restaurant dictionaries
data_3 = pd.DataFrame(restaurants)

# %%
data_3.columns
# Out:
# Index(['R', 'apikey', 'id', 'name', 'url', 'location', 'switch_to_order_menu',
#        'cuisines', 'average_cost_for_two', 'price_range', 'currency', 'offers',
#        'thumb', 'user_rating', 'photos_url', 'menu_url', 'featured_image',
#        'has_online_delivery', 'is_delivering_now', 'deeplink',
#        'has_table_booking', 'events_url', 'establishment_types',
#        'zomato_events', 'book_url', 'order_url', 'order_deeplink'],
#       dtype='object')

# %%
# Step 1: Extract relevant columns
columns_of_interest = [
    'has_online_delivery', 'price_range','user_rating', 'R', 'name', 'cuisines', 
    'is_delivering_now', 'average_cost_for_two', 'switch_to_order_menu',
    'has_table_booking', 'location','currency', 'id'
]

# %%
# Check if columns of interest exist in the DataFrame
existing_columns = [col for col in columns_of_interest if col in data_3.columns]
print("Existing columns:", existing_columns)  # Print the existing columns to see what's available
# Out:
# Existing columns: ['has_online_delivery', 'price_range', 'user_rating', 'R', 'name', 'cuisines', 'is_delivering_now', 'average_cost_for_two', 'switch_to_order_menu', 'has_table_booking', 'location', 'currency', 'id']

# %%
# Extract the relevant columns
data_3 = data_3[existing_columns]

# %%
data_3
# Out:
#       has_online_delivery  price_range  \
# 0                       0            4
# 1                       0            3
# 2                       0            1
# 3                       0            1
# 4                       0            1
# ...                   ...          ...
# 8681                    0            4
# 8682                    0            2
# 8683                    0            2
# 8684                    0            2
# 8685                    0            2
#
#                                             user_rating                     R  \
# 0     {'aggregate_rating': '4.9', 'rating_text': 'Ex...   {'res_id': 2100702}
# 1     {'aggregate_rating': '4.4', 'rating_text': 'Ve...  {'res_id': 16608059}
# 2     {'aggregate_rating': '4.3', 'rating_text': 'Ve...  {'res_id': 17558684}
# 3     {'aggregate_rating': '3.8', 'rating_text': 'Go...  {'res_id': 16604896}
# 4     {'aggregate_rating': '3.7', 'rating_text': 'Go...  {'res_id': 17536645}
# ...                                                 ...                   ...
# 8681  {'aggregate_rating': '4.3', 'rating_text': 'Ve...  {'res_id': 16512333}
# 8682  {'aggregate_rating': '3.2', 'rating_text': 'Av...  {'res_id': 17559793}
# 8683  {'aggregate_rating': '3.7', 'rating_text': 'Go...  {'res_id': 16607969}
# 8684  {'aggregate_rating': '3.5', 'rating_text': 'Go...  {'res_id': 17842104}
# 8685  {'aggregate_rating': '3.6', 'rating_text': 'Go...  {'res_id': 17687832}
#
#                                       name  \
# 0                          Barbeque Nation
# 1                      1918 Bistro & Grill
# 2                   Berry Patch Restaurant
# 3                La Trattoria of Lavandula
# 4     Jehova es Mi Pastor Tacos y Burritos
# ...                                    ...
# 8681             Britto's Bar & Restaurant
# 8682             Fishpatrick's Crabby Cafe
# 8683                       Bespoke Harvest
# 8684                                   Mr.
# 8685         Vince's Restaurant & Pizzeria
#
#                                          cuisines  is_delivering_now  \
# 0                                    North Indian                  0
# 1                   Modern Australian, Australian                  0
# 2                   American, Breakfast, Desserts                  0
# 3                           Italian, Fusion, Cafe                  0
# 4                                         Mexican                  0
# ...                                           ...                ...
# 8681  North Indian, Continental, Chinese, Seafood                  0
# 8682                       Burger, Seafood, Steak                  0
# 8683                             Cafe, Australian                  0
# 8684                                         Cafe                  0
# 8685                               Italian, Pizza                  0
#
#       average_cost_for_two  switch_to_order_menu  has_table_booking  \
# 0                     1500                     0                  0
# 1                       30                     0                  0
# 2                       10                     0                  0
# 3                        7                     0                  0
# 4                       10                     0                  0
# ...                    ...                   ...                ...
# 8681                  1400                     0                  0
# 8682                    25                     0                  0
# 8683                    20                     0                  0
# 8684                    20                     0                  0
# 8685                    25                     0                  0
#
#                                                location currency        id
# 0     {'address': '2nd Floor, Adityam Building, Ulub...      Rs.   2100702
# 1     {'address': '94 Murray St, Tanunda, SA', 'loca...        $  16608059
# 2     {'address': '49289 Us-30, Westport, OR 97016',...        $  17558684
# 3     {'address': '350 Hepburn-Newstead Road, Hepbur...        $  16604896
# 4     {'address': '135 W. Main Street, Fernley, NV 8...        $  17536645
# ...                                                 ...      ...       ...
# 8681  {'address': 'Baga Calangute, Bardez, Baga, Goa...      Rs.  16512333
# 8682  {'address': '196 Bayfront Loop, Winchester Bay...        $  17559793
# 8683  {'address': '16 Grant St, Forrest, VIC', 'loca...        $  16607969
# 8684  {'address': '23 Victoria St, Macedon, VIC', 'l...        $  17842104
# 8685  {'address': '619 4th Ave, Monroe, WI 53566', '...        $  17687832
#
# [8686 rows x 13 columns]

# %%
# If necessary, flatten the 'location' and 'user_rating' dictionaries
data_3['latitude'] = data_3['location'].apply(lambda x: x.get('latitude', None) if isinstance(x, dict) else None)
data_3['longitude'] = data_3['location'].apply(lambda x: x.get('longitude', None) if isinstance(x, dict) else None)
data_3['city'] = data_3['location'].apply(lambda x: x.get('city', None) if isinstance(x, dict) else None)
data_3['address'] = data_3['location'].apply(lambda x: x.get('address', None) if isinstance(x, dict) else None)
data_3['country_id'] = data_3['location'].apply(lambda x: x.get('country_id', None) if isinstance(x, dict) else None)
data_3['locality_verbose'] = data_3['location'].apply(lambda x: x.get('locality_verbose', None) if isinstance(x, dict) else None)
data_3['locality'] = data_3['location'].apply(lambda x: x.get('locality', None) if isinstance(x, dict) else None)

data_3['aggregate_rating'] = data_3['user_rating'].apply(lambda x: x.get('aggregate_rating', None) if isinstance(x, dict) else None)
data_3['rating_color'] = data_3['user_rating'].apply(lambda x: x.get('rating_color', None) if isinstance(x, dict) else None)
data_3['rating_text'] = data_3['user_rating'].apply(lambda x: x.get('rating_text', None) if isinstance(x, dict) else None)
data_3['votes'] = data_3['user_rating'].apply(lambda x: x.get('votes', None) if isinstance(x, dict) else None)

# Flatten the 'R' dictionary
data_3['res_id'] = data_3['R'].apply(lambda x: x.get('res_id', None) if isinstance(x, dict) else None)

# %%
# Drop the original 'location', 'user_rating', and 'R' columns if no longer needed
data_3.drop(columns=['location', 'user_rating', 'R'], inplace=True)

# %%
data_3.drop(columns=['id'], inplace=True)

# %%
data_3.head()
# Out:
#    has_online_delivery  price_range                                  name  \
# 0                    0            4                       Barbeque Nation
# 1                    0            3                   1918 Bistro & Grill
# 2                    0            1                Berry Patch Restaurant
# 3                    0            1             La Trattoria of Lavandula
# 4                    0            1  Jehova es Mi Pastor Tacos y Burritos
#
#                         cuisines  is_delivering_now  average_cost_for_two  \
# 0                   North Indian                  0                  1500
# 1  Modern Australian, Australian                  0                    30
# 2  American, Breakfast, Desserts                  0                    10
# 3          Italian, Fusion, Cafe                  0                     7
# 4                        Mexican                  0                    10
#
#    switch_to_order_menu  has_table_booking currency        latitude  ...  \
# 0                     0                  0      Rs.   26.1721190000  ...
# 1                     0                  0        $  -34.5196190000  ...
# 2                     0                  0        $   46.1269670000  ...
# 3                     0                  0        $  -37.2754940000  ...
# 4                     0                  0        $   39.6075150000  ...
#
#               city                                          address  \
# 0         Guwahati   2nd Floor, Adityam Building, Ulubari, Guwahati
# 1          Tanunda                        94 Murray St, Tanunda, SA
# 2       Clatskanie                  49289 Us-30, Westport, OR 97016
# 3  Hepburn Springs  350 Hepburn-Newstead Road, Hepburn Springs, VIC
# 4          Fernley            135 W. Main Street, Fernley, NV 89408
#
#   country_id                  locality_verbose         locality  \
# 0          1                 Ulubari, Guwahati          Ulubari
# 1         14                  Tanunda, Tanunda          Tanunda
# 2        216            Clatskanie, Clatskanie       Clatskanie
# 3         14  Hepburn Springs, Hepburn Springs  Hepburn Springs
# 4        216                  Fernley, Fernley          Fernley
#
#   aggregate_rating rating_color rating_text votes    res_id
# 0              4.9       3F7E00   Excellent   774   2100702
# 1              4.4       5BA829   Very Good   339  16608059
# 2              4.3       5BA829   Very Good    96  17558684
# 3              3.8       9ACD32        Good    93  16604896
# 4              3.7       9ACD32        Good    83  17536645
#
# [5 rows x 21 columns]

# %%
data_3.shape
# Out:
# (8686, 21)

# %% [markdown]
# # File4

# %%
# Load the dataset
data_4 = pd.read_json(r"C:\Users\Lenovo\Downloads\project 6\data set\file4.json")

# %%
data_4
# Out:
#      results_found  results_start  results_shown  \
# 0          1263908             61             20
# 1          1263908             61             20
# 2          1263908             61             20
# 3          1263908             61             20
# 4          1263908             61             20
# ..             ...            ...            ...
# 474        1263908             61             20
# 475        1263908             61             20
# 476        1263908             61             20
# 477        1263908             61             20
# 478        1263908             61             20
#
#                                            restaurants
# 0    [{'restaurant': {'R': {'res_id': 16604370}, 'a...
# 1    [{'restaurant': {'R': {'res_id': 16604370}, 'a...
# 2    [{'restaurant': {'R': {'res_id': 16604370}, 'a...
# 3    [{'restaurant': {'R': {'res_id': 16604370}, 'a...
# 4    [{'restaurant': {'R': {'res_id': 16604370}, 'a...
# ..                                                 ...
# 474  [{'restaurant': {'R': {'res_id': 16643459}, 'a...
# 475  [{'restaurant': {'R': {'res_id': 16643459}, 'a...
# 476  [{'restaurant': {'R': {'res_id': 16643459}, 'a...
# 477  [{'restaurant': {'R': {'res_id': 16643459}, 'a...
# 478  [{'restaurant': {'R': {'res_id': 16643459}, 'a...
#
# [479 rows x 4 columns]

# %%
# drop column from dataframe
data_4.drop(columns=["results_found","results_shown","results_start"],inplace=True,axis=1)

# %%
data_4
# Out:
#                                            restaurants
# 0    [{'restaurant': {'R': {'res_id': 16604370}, 'a...
# 1    [{'restaurant': {'R': {'res_id': 16604370}, 'a...
# 2    [{'restaurant': {'R': {'res_id': 16604370}, 'a...
# 3    [{'restaurant': {'R': {'res_id': 16604370}, 'a...
# 4    [{'restaurant': {'R': {'res_id': 16604370}, 'a...
# ..                                                 ...
# 474  [{'restaurant': {'R': {'res_id': 16643459}, 'a...
# 475  [{'restaurant': {'R': {'res_id': 16643459}, 'a...
# 476  [{'restaurant': {'R': {'res_id': 16643459}, 'a...
# 477  [{'restaurant': {'R': {'res_id': 16643459}, 'a...
# 478  [{'restaurant': {'R': {'res_id': 16643459}, 'a...
#
# [479 rows x 1 columns]

# %%
data_4.columns
# Out:
# Index(['restaurants'], dtype='object')

# %%
# Initialize an empty list to hold restaurant data
restaurants = []

# Extract the restaurant data from the nested structure
for restaurant_list in data_4['restaurants']:
    # Check if the restaurant_list is a list
    if isinstance(restaurant_list, list):  # Ensure it's a list before iterating
        for restaurant in restaurant_list:  # Each restaurant_list contains individual restaurant dictionaries
            if 'restaurant' in restaurant:  # Check if 'restaurant' key exists
                restaurants.append(restaurant['restaurant'])  # Append the 'restaurant' dictionary to the list

# %%
# Create a new DataFrame from the list of restaurant dictionaries
data_4 = pd.DataFrame(restaurants)

# %%
data_4.columns
# Out:
# Index(['R', 'apikey', 'id', 'name', 'url', 'location', 'switch_to_order_menu',
#        'cuisines', 'average_cost_for_two', 'price_range', 'currency', 'offers',
#        'thumb', 'user_rating', 'photos_url', 'menu_url', 'featured_image',
#        'has_online_delivery', 'is_delivering_now', 'deeplink',
#        'has_table_booking', 'events_url', 'establishment_types',
#        'zomato_events', 'book_url', 'order_url', 'order_deeplink'],
#       dtype='object')

# %%
# Step 1: Extract relevant columns
columns_of_interest = [
    'has_online_delivery', 'price_range','user_rating', 'R', 'name', 'cuisines', 
    'is_delivering_now', 'average_cost_for_two', 'switch_to_order_menu',
    'has_table_booking', 'location','currency', 'id'
]

# %%
# Check if columns of interest exist in the DataFrame
existing_columns = [col for col in columns_of_interest if col in data_4.columns]
print("Existing columns:", existing_columns)  # Print the existing columns to see what's available
# Out:
# Existing columns: ['has_online_delivery', 'price_range', 'user_rating', 'R', 'name', 'cuisines', 'is_delivering_now', 'average_cost_for_two', 'switch_to_order_menu', 'has_table_booking', 'location', 'currency', 'id']

# %%
# Extract the relevant columns
data_4 = data_4[existing_columns]

# %%
data_4
# Out:
#       has_online_delivery  price_range  \
# 0                       0            2
# 1                       0            2
# 2                       0            3
# 3                       1            2
# 4                       0            2
# ...                   ...          ...
# 8860                    0            1
# 8861                    0            3
# 8862                    0            2
# 8863                    0            3
# 8864                    0            3
#
#                                             user_rating                     R  \
# 0     {'aggregate_rating': '3.7', 'rating_text': 'Go...  {'res_id': 16604370}
# 1     {'aggregate_rating': '3.0', 'rating_text': 'Av...  {'res_id': 16643459}
# 2     {'aggregate_rating': '3.6', 'rating_text': 'Go...  {'res_id': 18185059}
# 3     {'aggregate_rating': '4.4', 'rating_text': 'Ve...  {'res_id': 18385186}
# 4     {'aggregate_rating': '4.1', 'rating_text': 'Ve...   {'res_id': 2200000}
# ...                                                 ...                   ...
# 8860  {'aggregate_rating': '3.6', 'rating_text': 'Go...  {'res_id': 17557488}
# 8861  {'aggregate_rating': '4.0', 'rating_text': 'Ve...  {'res_id': 18182702}
# 8862  {'aggregate_rating': '3.2', 'rating_text': 'Av...  {'res_id': 16608864}
# 8863  {'aggregate_rating': '4.8', 'rating_text': 'Ex...     {'res_id': 13231}
# 8864  {'aggregate_rating': '4.4', 'rating_text': 'Ve...  {'res_id': 16613649}
#
#                           name                                      cuisines  \
# 0               Mad Cowes Cafe  Breakfast, Coffee and Tea, Modern Australian
# 1           Consort Restaurant                             Chinese, Canadian
# 2                Cafe Arabelle             Cafe, American, Italian, Filipino
# 3              The Cafe Baraco                                 Cafe, Italian
# 4              Kesar Da Dhabha                                  North Indian
# ...                        ...                                           ...
# 8860     Burger Queen Drive In                    Burger, Desserts, Sandwich
# 8861  Nonna's Pasta & Pizzeria                                Italian, Pizza
# 8862         Taste of Balingup                             Modern Australian
# 8863                Le Plaisir                            European, Desserts
# 8864        Vivo Bar and Grill                        Mediterranean, Seafood
#
#       is_delivering_now  average_cost_for_two  switch_to_order_menu  \
# 0                     0                    20                     0
# 1                     0                    25                     0
# 2                     0                   800                     0
# 3                     0                   600                     0
# 4                     0                   500                     0
# ...                 ...                   ...                   ...
# 8860                  0                    10                     0
# 8861                  0                   850                     0
# 8862                  0                    20                     0
# 8863                  0                  1000                     0
# 8864                  0                    30                     0
#
#       has_table_booking                                           location  \
# 0                     0  {'address': '4/17 The Esplanade, Cowes, VIC', ...
# 1                     0  {'address': '4931 50th Street, Consort, AB T0C...
# 2                     0  {'address': 'Ayala Mall, Solenad, Nuvali, Sant...
# 3                     0  {'address': '34, Shribhuvan Complex, Near Memn...
# 4                     0  {'address': 'Near Telephone Exchange, Chowk Pa...
# ...                 ...                                                ...
# 8860                  0  {'address': '109 S F St, Lakeview, OR 97630', ...
# 8861                  0  {'address': 'Ground Floor, Building G, Solenad...
# 8862                  0  {'address': '63 South Western Hwy, Balingup, W...
# 8863                  0  {'address': '759/125, Rajkamal, Opposite Kelka...
# 8864                  0  {'address': '49 Williams Esplanade, Palm Cove,...
#
#      currency        id
# 0           $  16604370
# 1           $  16643459
# 2           P  18185059
# 3         Rs.  18385186
# 4         Rs.   2200000
# ...       ...       ...
# 8860        $  17557488
# 8861        P  18182702
# 8862        $  16608864
# 8863      Rs.     13231
# 8864        $  16613649
#
# [8865 rows x 13 columns]

# %%
# If necessary, flatten the 'location' and 'user_rating' dictionaries
data_4['latitude'] = data_4['location'].apply(lambda x: x.get('latitude', None) if isinstance(x, dict) else None)
data_4['longitude'] = data_4['location'].apply(lambda x: x.get('longitude', None) if isinstance(x, dict) else None)
data_4['city'] = data_4['location'].apply(lambda x: x.get('city', None) if isinstance(x, dict) else None)
data_4['address'] = data_4['location'].apply(lambda x: x.get('address', None) if isinstance(x, dict) else None)
data_4['country_id'] = data_4['location'].apply(lambda x: x.get('country_id', None) if isinstance(x, dict) else None)
data_4['locality_verbose'] = data_4['location'].apply(lambda x: x.get('locality_verbose', None) if isinstance(x, dict) else None)
data_4['locality'] = data_4['location'].apply(lambda x: x.get('locality', None) if isinstance(x, dict) else None)

data_4['aggregate_rating'] = data_4['user_rating'].apply(lambda x: x.get('aggregate_rating', None) if isinstance(x, dict) else None)
data_4['rating_color'] = data_4['user_rating'].apply(lambda x: x.get('rating_color', None) if isinstance(x, dict) else None)
data_4['rating_text'] = data_4['user_rating'].apply(lambda x: x.get('rating_text', None) if isinstance(x, dict) else None)
data_4['votes'] = data_4['user_rating'].apply(lambda x: x.get('votes', None) if isinstance(x, dict) else None)

# Flatten the 'R' dictionary
data_4['res_id'] = data_4['R'].apply(lambda x: x.get('res_id', None) if isinstance(x, dict) else None)

# %%
# Drop the original 'location', 'user_rating', and 'R' columns if no longer needed
data_4.drop(columns=['location', 'user_rating', 'R'], inplace=True)

# %%
data_4.drop(columns=['id'], inplace=True)

# %%
data_4.head()
# Out:
#    has_online_delivery  price_range                name  \
# 0                    0            2      Mad Cowes Cafe
# 1                    0            2  Consort Restaurant
# 2                    0            3       Cafe Arabelle
# 3                    1            2     The Cafe Baraco
# 4                    0            2     Kesar Da Dhabha
#
#                                        cuisines  is_delivering_now  \
# 0  Breakfast, Coffee and Tea, Modern Australian                  0
# 1                             Chinese, Canadian                  0
# 2             Cafe, American, Italian, Filipino                  0
# 3                                 Cafe, Italian                  0
# 4                                  North Indian                  0
#
#    average_cost_for_two  switch_to_order_menu  has_table_booking currency  \
# 0                    20                     0                  0        $
# 1                    25                     0                  0        $
# 2                   800                     0                  0        P
# 3                   600                     0                  0      Rs.
# 4                   500                     0                  0      Rs.
#
#          latitude  ...            city  \
# 0  -38.4483070000  ...  Phillip Island
# 1   52.0082889000  ...         Consort
# 2   14.2370820000  ...      Santa Rosa
# 3   23.0443367000  ...       Ahmedabad
# 4   31.6243860000  ...        Amritsar
#
#                                              address country_id  \
# 0                     4/17 The Esplanade, Cowes, VIC         14
# 1              4931 50th Street, Consort, AB T0C 1B0         37
# 2  Ayala Mall, Solenad, Nuvali, Santa Rosa - Taga...        162
# 3  34, Shribhuvan Complex, Near Memnagar Fire Sta...          1
# 4  Near Telephone Exchange, Chowk Passian, Shastr...          1
#
#                            locality_verbose                      locality  \
# 0            Phillip Island, Phillip Island                Phillip Island
# 1                          Consort, Consort                       Consort
# 2  Nuvali, Don Jose, Santa Rosa, Santa Rosa  Nuvali, Don Jose, Santa Rosa
# 3                    Navrangpura, Ahmedabad                   Navrangpura
# 4                       Town Hall, Amritsar                     Town Hall
#
#   aggregate_rating rating_color rating_text votes    res_id
# 0              3.7       9ACD32        Good   351  16604370
# 1              3.0       CDD614     Average     6  16643459
# 2              3.6       9ACD32        Good    29  18185059
# 3              4.4       5BA829   Very Good   317  18385186
# 4              4.1       5BA829   Very Good   878   2200000
#
# [5 rows x 21 columns]

# %%
data_4.shape
# Out:
# (8865, 21)

# %% [markdown]
# # File5

# %%
# Load the dataset
data_5 = pd.read_json(r"C:\Users\Lenovo\Downloads\project 6\data set\file5.json")

# %%
data_5
# Out:
#      results_found                                        restaurants  \
# 0              0.0                                                 []
# 1           6835.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 2              0.0                                                 []
# 3              0.0                                                 []
# 4           8680.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# ..             ...                                                ...
# 295            NaN                                                NaN
# 296            NaN                                                NaN
# 297            NaN                                                NaN
# 298            NaN                                                NaN
# 299            NaN                                                NaN
#
#      results_shown  results_start             message   code status
# 0              0.0            1.0                 NaN    NaN    NaN
# 1             20.0            1.0                 NaN    NaN    NaN
# 2              0.0            1.0                 NaN    NaN    NaN
# 3              0.0            1.0                 NaN    NaN    NaN
# 4             20.0            1.0                 NaN    NaN    NaN
# ..             ...            ...                 ...    ...    ...
# 295            NaN            NaN  API limit exceeded  440.0
# 296            NaN            NaN  API limit exceeded  440.0
# 297            NaN            NaN  API limit exceeded  440.0
# 298            NaN            NaN  API limit exceeded  440.0
# 299            NaN            NaN  API limit exceeded  440.0
#
# [300 rows x 7 columns]

# %%
# drop column from dataframe
data_5.drop(columns=["results_found","results_shown","results_start","message","code","status"],inplace=True,axis=1)

# %%
data_5
# Out:
#                                            restaurants
# 0                                                   []
# 1    [{'restaurant': {'has_online_delivery': 0, 'ph...
# 2                                                   []
# 3                                                   []
# 4    [{'restaurant': {'has_online_delivery': 0, 'ph...
# ..                                                 ...
# 295                                                NaN
# 296                                                NaN
# 297                                                NaN
# 298                                                NaN
# 299                                                NaN
#
# [300 rows x 1 columns]

# %%
data_5.columns
# Out:
# Index(['restaurants'], dtype='object')

# %%
# Initialize an empty list to hold restaurant data
restaurants = []

# Extract the restaurant data from the nested structure
for restaurant_list in data_5['restaurants']:
    # Check if the restaurant_list is a list
    if isinstance(restaurant_list, list):  # Ensure it's a list before iterating
        for restaurant in restaurant_list:  # Each restaurant_list contains individual restaurant dictionaries
            if 'restaurant' in restaurant:  # Check if 'restaurant' key exists
                restaurants.append(restaurant['restaurant'])  # Append the 'restaurant' dictionary to the list

# %%
# Create a new DataFrame from the list of restaurant dictionaries
data_5 = pd.DataFrame(restaurants)

# %%
data_5.columns
# Out:
# Index(['has_online_delivery', 'photos_url', 'url', 'price_range', 'apikey',
#        'user_rating', 'R', 'name', 'has_table_booking', 'is_delivering_now',
#        'deeplink', 'menu_url', 'average_cost_for_two', 'switch_to_order_menu',
#        'offers', 'cuisines', 'location', 'featured_image', 'currency', 'id',
#        'thumb', 'establishment_types', 'events_url'],
#       dtype='object')

# %%
# Step 1: Extract relevant columns
columns_of_interest = [
    'has_online_delivery', 'price_range','user_rating', 'R', 'name', 'cuisines', 
    'is_delivering_now', 'average_cost_for_two', 'switch_to_order_menu',
    'has_table_booking', 'location','currency', 'id'
]

# %%
# Check if columns of interest exist in the DataFrame
existing_columns = [col for col in columns_of_interest if col in data_5.columns]
print("Existing columns:", existing_columns)  # Print the existing columns to see what's available
# Out:
# Existing columns: ['has_online_delivery', 'price_range', 'user_rating', 'R', 'name', 'cuisines', 'is_delivering_now', 'average_cost_for_two', 'switch_to_order_menu', 'has_table_booking', 'location', 'currency', 'id']

# %%
# Extract the relevant columns
data_5 = data_5[existing_columns]

# %%
data_5
# Out:
#      has_online_delivery  price_range  \
# 0                      0            2
# 1                      0            4
# 2                      0            1
# 3                      0            3
# 4                      0            3
# ..                   ...          ...
# 415                    0            1
# 416                    0            3
# 417                    0            3
# 418                    0            1
# 419                    0            1
#
#                                            user_rating                     R  \
# 0    {'rating_text': 'Good', 'rating_color': '9ACD3...  {'res_id': 17066603}
# 1    {'rating_text': 'Very Good', 'rating_color': '...  {'res_id': 17059541}
# 2    {'rating_text': 'Very Good', 'rating_color': '...  {'res_id': 17064405}
# 3    {'rating_text': 'Very Good', 'rating_color': '...  {'res_id': 17057797}
# 4    {'rating_text': 'Very Good', 'rating_color': '...  {'res_id': 17057591}
# ..                                                 ...                   ...
# 415  {'rating_text': 'Good', 'rating_color': '9ACD3...  {'res_id': 17582627}
# 416  {'rating_text': 'Good', 'rating_color': '9ACD3...  {'res_id': 17582625}
# 417  {'rating_text': 'Good', 'rating_color': '9ACD3...  {'res_id': 17582668}
# 418  {'rating_text': 'Good', 'rating_color': '9ACD3...  {'res_id': 17582498}
# 419  {'rating_text': 'Good', 'rating_color': '9ACD3...  {'res_id': 17582499}
#
#                               name                           cuisines  \
# 0                         The Coop         Southern, Cajun, Soul Food
# 1          Maggiano's Little Italy                            Italian
# 2           Tako Cheena by Pom Pom  Asian, Latin American, Vegetarian
# 3       Bosphorous Turkish Cuisine             Mediterranean, Turkish
# 4      Bahama Breeze Island Grille                          Caribbean
# ..                             ...                                ...
# 415                  Senor Iguanas                            Mexican
# 416  Sandpiper Restaurant & Lounge           American, Seafood, Steak
# 417                Texas Roadhouse               American, BBQ, Steak
# 418                 Riverwalk Cafe                        Asian, Thai
# 419                    Royal Hotel                    Pizza, Bar Food
#
#      is_delivering_now  average_cost_for_two  switch_to_order_menu  \
# 0                    0                    25                     0
# 1                    0                    50                     0
# 2                    0                    10                     0
# 3                    0                    40                     0
# 4                    0                    45                     0
# ..                 ...                   ...                   ...
# 415                  0                     0                     0
# 416                  0                    40                     0
# 417                  0                    45                     0
# 418                  0                    10                     0
# 419                  0                     0                     0
#
#      has_table_booking                                           location  \
# 0                    0  {'latitude': '28.5973660000', 'address': '610 ...
# 1                    0  {'latitude': '28.4332350000', 'address': '9101...
# 2                    0  {'latitude': '28.5578450000', 'address': '932 ...
# 3                    0  {'latitude': '28.5976271000', 'address': '108 ...
# 4                    0  {'latitude': '28.4370650000', 'address': '8849...
# ..                 ...                                                ...
# 415                  0  {'latitude': '42.8942000000', 'address': '961 ...
# 416                  0  {'latitude': '42.9012000000', 'address': '1400...
# 417                  0  {'latitude': '42.9105180000', 'address': '560 ...
# 418                  0  {'latitude': '42.6200000000', 'address': '695 ...
# 419                  0  {'latitude': '42.6192000000', 'address': '11 E...
#
#     currency        id
# 0          $  17066603
# 1          $  17059541
# 2          $  17064405
# 3          $  17057797
# 4          $  17057591
# ..       ...       ...
# 415        $  17582627
# 416        $  17582625
# 417        $  17582668
# 418        $  17582498
# 419        $  17582499
#
# [420 rows x 13 columns]

# %%
# If necessary, flatten the 'location' and 'user_rating' dictionaries
data_5['latitude'] = data_5['location'].apply(lambda x: x.get('latitude', None) if isinstance(x, dict) else None)
data_5['longitude'] = data_5['location'].apply(lambda x: x.get('longitude', None) if isinstance(x, dict) else None)
data_5['city'] = data_5['location'].apply(lambda x: x.get('city', None) if isinstance(x, dict) else None)
data_5['address'] = data_5['location'].apply(lambda x: x.get('address', None) if isinstance(x, dict) else None)
data_5['country_id'] = data_5['location'].apply(lambda x: x.get('country_id', None) if isinstance(x, dict) else None)
data_5['locality_verbose'] = data_5['location'].apply(lambda x: x.get('locality_verbose', None) if isinstance(x, dict) else None)
data_5['locality'] = data_5['location'].apply(lambda x: x.get('locality', None) if isinstance(x, dict) else None)

data_5['aggregate_rating'] = data_5['user_rating'].apply(lambda x: x.get('aggregate_rating', None) if isinstance(x, dict) else None)
data_5['rating_color'] = data_5['user_rating'].apply(lambda x: x.get('rating_color', None) if isinstance(x, dict) else None)
data_5['rating_text'] = data_5['user_rating'].apply(lambda x: x.get('rating_text', None) if isinstance(x, dict) else None)
data_5['votes'] = data_5['user_rating'].apply(lambda x: x.get('votes', None) if isinstance(x, dict) else None)

# Flatten the 'R' dictionary
data_5['res_id'] = data_5['R'].apply(lambda x: x.get('res_id', None) if isinstance(x, dict) else None)

# %%
# Drop the original 'location', 'user_rating', and 'R' columns if no longer needed
data_5.drop(columns=['location', 'user_rating', 'R'], inplace=True)

# %%
data_5.drop(columns=['id'], inplace=True)

# %%
data_5.head()
# Out:
#    has_online_delivery  price_range                         name  \
# 0                    0            2                     The Coop
# 1                    0            4      Maggiano's Little Italy
# 2                    0            1       Tako Cheena by Pom Pom
# 3                    0            3   Bosphorous Turkish Cuisine
# 4                    0            3  Bahama Breeze Island Grille
#
#                             cuisines  is_delivering_now  average_cost_for_two  \
# 0         Southern, Cajun, Soul Food                  0                    25
# 1                            Italian                  0                    50
# 2  Asian, Latin American, Vegetarian                  0                    10
# 3             Mediterranean, Turkish                  0                    40
# 4                          Caribbean                  0                    45
#
#    switch_to_order_menu  has_table_booking currency       latitude  ...  \
# 0                     0                  0        $  28.5973660000  ...
# 1                     0                  0        $  28.4332350000  ...
# 2                     0                  0        $  28.5578450000  ...
# 3                     0                  0        $  28.5976271000  ...
# 4                     0                  0        $  28.4370650000  ...
#
#       city                                       address country_id  \
# 0  Orlando  610 W Morse Boulevard, Winter Park, FL 32789        216
# 1  Orlando    9101 International Drive,Orlando, FL 32819        216
# 2  Orlando     932 North Mills Avenue, Orlando, FL 32803        216
# 3  Orlando         108 S Park Ave, Winter Park, FL 32789        216
# 4  Orlando   8849 International Drive, Orlando, FL 32819        216
#
#              locality_verbose           locality aggregate_rating  \
# 0        Winter Park, Orlando        Winter Park              3.6
# 1  I-Drive/Universal, Orlando  I-Drive/Universal              4.4
# 2           Mills 50, Orlando           Mills 50              4.4
# 3        Winter Park, Orlando        Winter Park              4.2
# 4  I-Drive/Universal, Orlando  I-Drive/Universal              4.3
#
#   rating_color rating_text votes    res_id
# 0       9ACD32        Good   432  17066603
# 1       5BA829   Very Good   886  17059541
# 2       5BA829   Very Good   570  17064405
# 3       5BA829   Very Good   568  17057797
# 4       5BA829   Very Good   910  17057591
#
# [5 rows x 21 columns]

# %%
data_5.shape
# Out:
# (420, 21)

# %%
# List of DataFrames to concatenate
dataframes = [data_1, data_2, data_3, data_4, data_5]

# %%
# Concatenate DataFrames vertically
combined_df = pd.concat(dataframes, ignore_index=True)

# %%
# Check the result
combined_df.head()
# Out:
#    has_online_delivery  price_range                        name  \
# 0                    1            3            Hauz Khas Social
# 1                    0            3  Qubitos - The Terrace Cafe
# 2                    1            2             The Hudson Cafe
# 3                    0            3           Summer House Cafe
# 4                    0            3                 38 Barracks
#
#                                             cuisines  is_delivering_now  \
# 0         Continental, American, Asian, North Indian                  0
# 1  Thai, European, Mexican, North Indian, Chinese...                  0
# 2                Cafe, Italian, Continental, Chinese                  0
# 3                               Italian, Continental                  0
# 4             North Indian, Italian, Asian, American                  0
#
#    average_cost_for_two  switch_to_order_menu  has_table_booking currency  \
# 0                  1600                     0                  1      Rs.
# 1                  1500                     0                  1      Rs.
# 2                   850                     0                  0      Rs.
# 3                  1850                     0                  1      Rs.
# 4                  1600                     0                  1      Rs.
#
#         latitude  ...       city  \
# 0  28.5542851000  ...  New Delhi
# 1  28.6471325000  ...  New Delhi
# 2  28.6949468000  ...  New Delhi
# 3  28.5525204000  ...  New Delhi
# 4  28.6330248887  ...  New Delhi
#
#                                              address country_id  \
# 0             9-A & 12, Hauz Khas Village, New Delhi          1
# 1  C-7, Vishal Enclave, Opposite Metro Pillar 417...          1
# 2  2524, 1st Floor, Hudson Lane, Delhi University...          1
# 3  1st Floor, DDA Shopping Complex, Aurobindo Pla...          1
# 4     M-38, Outer Circle, Connaught Place, New Delhi          1
#
#                         locality_verbose                    locality  \
# 0           Hauz Khas Village, New Delhi           Hauz Khas Village
# 1              Rajouri Garden, New Delhi              Rajouri Garden
# 2  Delhi University-GTB Nagar, New Delhi  Delhi University-GTB Nagar
# 3                   Hauz Khas, New Delhi                   Hauz Khas
# 4             Connaught Place, New Delhi             Connaught Place
#
#   aggregate_rating rating_color rating_text votes    res_id
# 0              4.3       5BA829   Very Good  7931    308322
# 1              4.5       3F7E00   Excellent   778  18037817
# 2              4.4       5BA829   Very Good  1537    312345
# 3              4.1       5BA829   Very Good  1823    307490
# 4              4.4       5BA829   Very Good   840  18241537
#
# [5 rows x 21 columns]

# %%
combined_df.shape  # Check the shape of the combined DataFrame
# Out:
# (29753, 21)

# %%
#Renaming specific columns after concatenation
combined_df = combined_df.rename(columns={
    'has_online_delivery': 'Has_Online_delivery',
    'price_range': 'Price_range',
    'name': 'Restaurant_name',
    'cuisines': 'Cuisines',
    'is_delivering_now': 'Is_delivering_now',
    'average_cost_for_two': 'Average_Cost_for_two',
    'switch_to_order_menu': 'Switch_to_order_menu',
    'has_table_booking': 'Has_Table_Booking',
    'currency': 'Currency',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'city': 'City',
    'address': 'Address',
    'aggregate_rating': 'Aggregate_rating',
    'rating_color': 'Rating_color',
    'rating_text': 'Rating_text',
    'res_id': 'Restaurant_id',
    'votes': 'Votes',
    'locality': 'Locality',
    'country_id': 'Country_code',
    'locality_verbose': 'Locality_Verbose'
})

# %%
combined_df.head()
# Out:
#    Has_Online_delivery  Price_range             Restaurant_name  \
# 0                    1            3            Hauz Khas Social
# 1                    0            3  Qubitos - The Terrace Cafe
# 2                    1            2             The Hudson Cafe
# 3                    0            3           Summer House Cafe
# 4                    0            3                 38 Barracks
#
#                                             Cuisines  Is_delivering_now  \
# 0         Continental, American, Asian, North Indian                  0
# 1  Thai, European, Mexican, North Indian, Chinese...                  0
# 2                Cafe, Italian, Continental, Chinese                  0
# 3                               Italian, Continental                  0
# 4             North Indian, Italian, Asian, American                  0
#
#    Average_Cost_for_two  Switch_to_order_menu  Has_Table_Booking Currency  \
# 0                  1600                     0                  1      Rs.
# 1                  1500                     0                  1      Rs.
# 2                   850                     0                  0      Rs.
# 3                  1850                     0                  1      Rs.
# 4                  1600                     0                  1      Rs.
#
#         Latitude  ...       City  \
# 0  28.5542851000  ...  New Delhi
# 1  28.6471325000  ...  New Delhi
# 2  28.6949468000  ...  New Delhi
# 3  28.5525204000  ...  New Delhi
# 4  28.6330248887  ...  New Delhi
#
#                                              Address Country_code  \
# 0             9-A & 12, Hauz Khas Village, New Delhi            1
# 1  C-7, Vishal Enclave, Opposite Metro Pillar 417...            1
# 2  2524, 1st Floor, Hudson Lane, Delhi University...            1
# 3  1st Floor, DDA Shopping Complex, Aurobindo Pla...            1
# 4     M-38, Outer Circle, Connaught Place, New Delhi            1
#
#                         Locality_Verbose                    Locality  \
# 0           Hauz Khas Village, New Delhi           Hauz Khas Village
# 1              Rajouri Garden, New Delhi              Rajouri Garden
# 2  Delhi University-GTB Nagar, New Delhi  Delhi University-GTB Nagar
# 3                   Hauz Khas, New Delhi                   Hauz Khas
# 4             Connaught Place, New Delhi             Connaught Place
#
#   Aggregate_rating Rating_color Rating_text Votes Restaurant_id
# 0              4.3       5BA829   Very Good  7931        308322
# 1              4.5       3F7E00   Excellent   778      18037817
# 2              4.4       5BA829   Very Good  1537        312345
# 3              4.1       5BA829   Very Good  1823        307490
# 4              4.4       5BA829   Very Good   840      18241537
#
# [5 rows x 21 columns]

# %%
combined_df.columns
# Out:
# Index(['Has_Online_delivery', 'Price_range', 'Restaurant_name', 'Cuisines',
#        'Is_delivering_now', 'Average_Cost_for_two', 'Switch_to_order_menu',
#        'Has_Table_Booking', 'Currency', 'Latitude', 'Longitude', 'City',
#        'Address', 'Country_code', 'Locality_Verbose', 'Locality',
#        'Aggregate_rating', 'Rating_color', 'Rating_text', 'Votes',
#        'Restaurant_id'],
#       dtype='object')

# %%
# Specify the new order of columns
new_column_order = ['Restaurant_id', 'Restaurant_name', 'Country_code', 'City', 
                    'Address', 'Locality', 'Locality_Verbose', 'Longitude', 'Latitude', 
                    'Cuisines', 'Average_Cost_for_two', 'Currency', 'Has_Table_Booking', 
                    'Has_Online_delivery', 'Is_delivering_now', 'Switch_to_order_menu', 
                    'Price_range', 'Aggregate_rating', 'Rating_color', 'Rating_text', 'Votes']

# %%
# Reassign the columns in the new order
combined_df = combined_df[new_column_order]

# %%
combined_df.head()
# Out:
#    Restaurant_id             Restaurant_name  Country_code       City  \
# 0         308322            Hauz Khas Social             1  New Delhi
# 1       18037817  Qubitos - The Terrace Cafe             1  New Delhi
# 2         312345             The Hudson Cafe             1  New Delhi
# 3         307490           Summer House Cafe             1  New Delhi
# 4       18241537                 38 Barracks             1  New Delhi
#
#                                              Address  \
# 0             9-A & 12, Hauz Khas Village, New Delhi
# 1  C-7, Vishal Enclave, Opposite Metro Pillar 417...
# 2  2524, 1st Floor, Hudson Lane, Delhi University...
# 3  1st Floor, DDA Shopping Complex, Aurobindo Pla...
# 4     M-38, Outer Circle, Connaught Place, New Delhi
#
#                      Locality                       Locality_Verbose  \
# 0           Hauz Khas Village           Hauz Khas Village, New Delhi
# 1              Rajouri Garden              Rajouri Garden, New Delhi
# 2  Delhi University-GTB Nagar  Delhi University-GTB Nagar, New Delhi
# 3                   Hauz Khas                   Hauz Khas, New Delhi
# 4             Connaught Place             Connaught Place, New Delhi
#
#        Longitude       Latitude  \
# 0  77.1944706000  28.5542851000
# 1  77.1177015000  28.6471325000
# 2  77.2043172000  28.6949468000
# 3  77.2038090000  28.5525204000
# 4  77.2228584811  28.6330248887
#
#                                             Cuisines  ...  Currency  \
# 0         Continental, American, Asian, North Indian  ...       Rs.
# 1  Thai, European, Mexican, North Indian, Chinese...  ...       Rs.
# 2                Cafe, Italian, Continental, Chinese  ...       Rs.
# 3                               Italian, Continental  ...       Rs.
# 4             North Indian, Italian, Asian, American  ...       Rs.
#
#   Has_Table_Booking  Has_Online_delivery  Is_delivering_now  \
# 0                 1                    1                  0
# 1                 1                    0                  0
# 2                 0                    1                  0
# 3                 1                    0                  0
# 4                 1                    0                  0
#
#    Switch_to_order_menu  Price_range  Aggregate_rating Rating_color  \
# 0                     0            3               4.3       5BA829
# 1                     0            3               4.5       3F7E00
# 2                     0            2               4.4       5BA829
# 3                     0            3               4.1       5BA829
# 4                     0            3               4.4       5BA829
#
#   Rating_text Votes
# 0   Very Good  7931
# 1   Excellent   778
# 2   Very Good  1537
# 3   Very Good  1823
# 4   Very Good   840
#
# [5 rows x 21 columns]

# %%
# Save combined_df to a CSV file
combined_df.to_csv('Zomato_combined_data.csv', index=False)

# %%
# upload the combined data to s3
file_path = r"C:\Users\Lenovo\Downloads\project 6\Zomato_combined_data.csv"
s3_client.upload_file(file_path,'restaurantdata-bucket',r"C:\Users\Lenovo\Downloads\project 6\Zomato_combined_data.csv") #folder/filename
